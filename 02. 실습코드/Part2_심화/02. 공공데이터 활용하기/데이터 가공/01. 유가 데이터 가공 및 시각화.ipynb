# %% [markdown]
# # 주유소 가격 비교

# %%
import pandas as pd
import numpy as np

stations = pd.read_csv("./과거_판매가격(주유소)20190801-20190817.csv", encoding="cp949")
stations.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190801  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190802  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190803  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190804  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190805  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1777  1595  1495     0
# 1   1777  1595  1495     0
# 2   1777  1595  1495     0
# 3   1777  1595  1495     0
# 4   1777  1595  1495     0

# %%
stations['시'] = [eachAddress.split()[0] for eachAddress in stations['지역']]
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['지역']]

stations.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190801  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190802  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190803  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190804  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190805  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유   시    구
# 0   1777  1595  1495     0  서울  강남구
# 1   1777  1595  1495     0  서울  강남구
# 2   1777  1595  1495     0  서울  강남구
# 3   1777  1595  1495     0  서울  강남구
# 4   1777  1595  1495     0  서울  강남구

# %%
stations['구'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
stations['시'].unique()
# Out:
# array(['서울'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
stations.boxplot(column='휘발유', by='셀프여부', figsize=(12,8));

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="휘발유", hue="셀프여부", data=stations, palette="Set1")
plt.show()

# %%
stations.sort_values(by='휘발유', ascending=False).head(10)
# Out:
#             번호     지역     상호            주소        기간     상표 셀프여부  고급휘발유   휘발유  \
# 8030  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190802  SK에너지   일반   2601  2251
# 8041  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190813  SK에너지   일반   2601  2251
# 8029  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190801  SK에너지   일반   2601  2251
# 8031  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190803  SK에너지   일반   2601  2251
# 8032  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190804  SK에너지   일반   2601  2251
# 8033  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190805  SK에너지   일반   2601  2251
# 8034  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190806  SK에너지   일반   2601  2251
# 8035  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190807  SK에너지   일반   2601  2251
# 8037  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190809  SK에너지   일반   2601  2251
# 8038  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20190810  SK에너지   일반   2601  2251
#
#         경유  실내등유   시   구
# 8030  2121     0  서울  중구
# 8041  2126     0  서울  중구
# 8029  2121     0  서울  중구
# ...

# %%
stations.sort_values(by='휘발유', ascending=True).head(100)
# Out:
#             번호      지역                 상호                    주소        기간  \
# 951   A0009641  서울 강북구           (주)석산에너지  서울 강북구 삼양로 316 (수유동)  20190801
# 952   A0009641  서울 강북구           (주)석산에너지  서울 강북구 삼양로 316 (수유동)  20190802
# 964   A0009641  서울 강북구           (주)석산에너지  서울 강북구 삼양로 316 (수유동)  20190814
# 960   A0009641  서울 강북구           (주)석산에너지  서울 강북구 삼양로 316 (수유동)  20190810
# 961   A0009641  서울 강북구           (주)석산에너지  서울 강북구 삼양로 316 (수유동)  20190811
# ...        ...     ...                ...                   ...       ...
# 7829  A0000571  서울 은평구             타이거주유소  서울 은평구 수색로 188 (증산동)  20190805
# 7554  A0000707  서울 은평구  (주)명연에너지 수색훼미리주유소  서울 은평구 수색로 236 (수색동)  20190802
# 7841  A0000571  서울 은평구             타이거주유소  서울 은평구 수색로 188 (증산동)  20190817
# 7556  A0000707  서울 은평구  (주)명연에너지 수색훼미리주유소  서울 은평구 수색로 236 (수색동)  20190804
# 7555  A0000707  서울 은평구  (주)명연에너지 수색훼미리주유소  서울 은평구 수색로 236 (수색동)  20190803
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유   시    구
# ...

# %%
import numpy as np

gu_data = pd.pivot_table(stations, index=["구"], values=["휘발유"], 
                         aggfunc=np.mean)
gu_data
# Out:
#               휘발유
# 구
# 강남구   1734.873343
# 강동구   1584.790441
# 강북구   1468.140271
# 강서구   1507.653979
# 관악구   1542.073529
# 광진구   1509.032680
# 구로구   1542.828877
# 금천구   1490.945701
# 노원구   1557.376471
# 도봉구   1525.173375
# 동대문구  1527.930481
# 동작구   1525.829412
# 마포구   1728.821429
# 서대문구  1550.250980
# 서초구   1597.775835
# 성동구   1600.034843
# 성북구   1543.034759
# 송파구   1543.367647
# 양천구   1530.445755
# 영등포구  1572.415441
# 용산구   1900.682353
# 은평구   1508.328720
# 종로구   1863.555556
# 중구    2005.833333
# 중랑구   1492.180147

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
oil_price_top10 = stations.sort_values(by='휘발유', ascending=False).head(100)
oil_price_top10
# Out:
#             번호     지역              상호             주소        기간     상표 셀프여부  \
# 8030  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190802  SK에너지   일반
# 8041  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190813  SK에너지   일반
# 8029  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190801  SK에너지   일반
# 8031  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190803  SK에너지   일반
# 8032  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190804  SK에너지   일반
# ...        ...    ...             ...            ...       ...    ...  ...
# 8120  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190807  GS칼텍스   일반
# 8119  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190806  GS칼텍스   일반
# 8118  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190805  GS칼텍스   일반
# 8117  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190804  GS칼텍스   일반
# 8116  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190803  GS칼텍스   일반
#
#       고급휘발유   휘발유    경유  실내등유   시   구
# ...

# %%
gmap_key = "AIzaSyBdC5opUnusQZ28A8kZKiP0CM4eD03DMEs"
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# ...
#             번호     지역              상호             주소        기간     상표 셀프여부  \
# 8030  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190802  SK에너지   일반
# 8041  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190813  SK에너지   일반
# 8029  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190801  SK에너지   일반
# 8031  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190803  SK에너지   일반
# 8032  A0000767  서울 중구           서남주유소   서울 중구 통일로 30  20190804  SK에너지   일반
# ...        ...    ...             ...            ...       ...    ...  ...
# 8120  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190807  GS칼텍스   일반
# 8119  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190806  GS칼텍스   일반
# 8118  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190805  GS칼텍스   일반
# 8117  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190804  GS칼텍스   일반
# 8116  A0009058  서울 중구  지에스칼텍스(주)초동주유소  서울 중구 마른내로 31  20190803  GS칼텍스   일반
#
#       고급휘발유   휘발유    경유  실내등유   시   구        lat         lng
# ...

# %%
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                                  radius=10, color='#CD3181', 
                                  fill_color='#CD3181',
                                  fill=True).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
